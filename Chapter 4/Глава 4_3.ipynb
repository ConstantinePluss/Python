# %% [markdown]
# # 4. Статистический анализ данных

# %% [markdown]
# ## 3. Взаимосвязь данных

# %% [markdown]
# ### 3.1

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


df = pd.read_csv('new_ekb_weather.csv')
df = df.drop('Unnamed: 0', axis=1)
df['date'] = pd.to_datetime(df['date'])
print(df)
# Out:
#                     date  temp  pressure  humidity    month
# 0    2019-12-31 23:00:00  -9.2     743.1        76  Декабрь
# 1    2019-12-31 20:00:00  -8.8     744.1        75  Декабрь
# 2    2019-12-31 17:00:00  -7.9     744.5        82  Декабрь
# 3    2019-12-31 14:00:00 -11.5     745.9        85  Декабрь
# 4    2019-12-31 11:00:00 -12.8     749.0        84  Декабрь
# ...                  ...   ...       ...       ...      ...
# 2914 2019-01-01 14:00:00 -10.6     770.8        71   Январь
# 2915 2019-01-01 11:00:00 -11.9     771.3        75   Январь
# 2916 2019-01-01 08:00:00 -12.8     770.9        75   Январь
# 2917 2019-01-01 05:00:00 -12.8     770.9        75   Январь
# 2918 2019-01-01 02:00:00 -11.8     770.6        75   Январь
#
# [2919 rows x 5 columns]

# %%
pearson_temp_pressure = df['temp'].corr(df['pressure']) 
pearson_temp_humidity = df['temp'].corr(df['humidity']) 
pearson_pressure_humidity = df['pressure'].corr(df['humidity']) 

print('Коэффициент Пирсона\n'
	'Температура/давление: {pearson_temp_pressure}\n'
	'Температура/влажность: {pearson_temp_humidity}\n'
	'Давление/влажность: {pearson_pressure_humidity}\n'.format(pearson_temp_pressure = pearson_temp_pressure,
	pearson_temp_humidity = pearson_temp_humidity, pearson_pressure_humidity = pearson_pressure_humidity ))
print('Корреляция данных покоэффициенту Пирсона для всех данных \n', df.corr(numeric_only = True))
# Out:
# Коэффициент Пирсона
# Температура/давление: -0.4138849823503927
# Температура/влажность: -0.4202780710855227
# Давление/влажность: -0.09328804667790631
#
# Корреляция данных покоэффициенту Пирсона для всех данных
#                temp  pressure  humidity
# temp      1.000000 -0.413885 -0.420278
# pressure -0.413885  1.000000 -0.093288
# humidity -0.420278 -0.093288  1.000000

# %% [markdown]
# ### 3.2

# %%
pd.plotting.scatter_matrix(df, alpha = 0.5)
plt.show()
